# %%
import base64
with open("google_sheet_creds.json", "rb") as f:
    encoded_credentials = base64.b64encode(f.read()).decode("utf-8")
    print(encoded_credentials)
# Out:
# ...

# %%
from io import BytesIO


encoded_creds = "..."
padding = len(encoded_creds) % 4
if padding != 0:
    encoded_creds += "=" * (4 - padding)


creds_json = base64.b64decode(encoded_creds)
creds_file = BytesIO(creds_json)

creds_json
# Out:
# b'{\n  "type": "service_account",\n  "project_id": "heroic-builder-454311-q1",\n  "private_key_id": "0d44b7083fa7c0cda9224c143f6afca8046229c2",\n  "private_key": "-----BEGIN PRIVATE KEY-----\\nMIIEvQIBADANBgkqhkiG9w0BAQEFAASCBKcwggSjAgEAAoIBAQCYzw6dvyFzOq9Q\\n3xzHNXjNSWE55VQDK/Lxtr7JQGwGy5IQ0qeK6ciNqnzrSZCVCxBERv7QEMwQM44+\\nDiVPZ4kFzS+qg8jRYwpka1dW/oSjxWPiFyCkYScJ16XKI11FXnXjHjoqg1APz5mW\\n1aVNF82k2mdnWizxHALQflrQ9LWmwuTJF9j/g1vW367//5sFMi+2zzfCkkQxyxF4\\nQtwtqpbdzCDaUptBTOn9DmOSBEfhV0DDVvdKTNo4qA2DWaZ0gQHPpyg/jWlSOnuZ\\ncQ7J9VTXIWP+u92/Rqh0l3OtChkdHhpPSlZyy7X731flblP2OBiL9I1Ukth3tApu\\nEBkwo0WLAgMBAAECggEAE7l6dgNDYpfbJHHASbiNwNXtfmcrOoOURv4jT2AI8bGa\\nR6Chbs1xjVPJ7yceShbVATM21g2tAZReEoWJ7F99cOnE8toy9FA3+bFfY0PURD2J\\nAJiipoVB4EPdSyPYeMlSJ0ByGqW7kmbmOPGX9kURzutAOLeLoI3QkTAWMe28eutv\\nKaTTLW4fG8WEN4ctmG20N7ddcWGpXVoBzy4O9iaWJgtAA70gzVtYHtNZj7pBHfvH\\nLOOfnQBr+XIJllb042Jmd6kWxx6qI9WDb1Ag5RCA6w/qdrKBgd3rVuJm6j/KUC0b\\nbhhuKtzcJWZZapXzTdTh41JQ9bEmd6GIYP2mvBpEpQKBgQDSyoJTGQ2YAik0XloV\\n3
# ...
